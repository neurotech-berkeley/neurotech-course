# %% [markdown]
# # Electromyography (CS 198-96: Intro to Neurotechnology)
# ### v1 (Spring 2020) - Deven Navani
#
# Cool stuff with EMG

# %% [markdown]
# ## Datasets

# %% [markdown]
# EMG data for gestures: https://archive.ics.uci.edu/ml/datasets/EMG+data+for+gestures
